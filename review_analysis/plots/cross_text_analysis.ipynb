# %%
import pandas as pd
import numpy as np
import re
from kiwipiepy import Kiwi
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
nltk.download("punkt")
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /Users/lee/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df1 = pd.read_csv("/Users/lee/Desktop/0Moi/0git/YBIGTA_newbie_team_project/database/preprocessed_reviews_diningcode.csv")
df2 = pd.read_csv("/Users/lee/Desktop/0Moi/0git/YBIGTA_newbie_team_project/database/preprocessed_reviews_kakao.csv")
df3 = pd.read_csv("/Users/lee/Desktop/0Moi/0git/YBIGTA_newbie_team_project/database/preprocessed_reviews_google.csv")

# %%
df11 = df1["processed_text"]

# %%
df2 = df2.dropna(subset=["clean_review"])

# %%
df22 = df2["clean_review"]

# %%
df3 = df3.dropna(subset=["processed_text"])

# %%
df33 = df3["processed_text"]

# %%
newdf = pd.concat([df11,df22,df33],ignore_index=True)
newdf.reset_index(drop=True, inplace=True)
newdf = newdf.to_frame(name='clean_review')

# %%
df11.shape # 208 0~ 207
df22.shape # 897 208 ~ 1104
df33.shape # 704 1105 ~ 1808
# Out:
# (704,)

# %%
newdf
# Out:
#                                            clean_review
# 0     대전 용운 국제 수영장 대회 천안 성심당 본점 위치 상황 정오 주차장 주차 네이버 ...
# 1                    봉지 부띠끄 사람 비닐 주심 센스 메아리 대전 사람 다음 대전
# 2     대전 여행 알파 오메가 성심당 본점 대전 시내 위치 기차 도보 거리 주차 주차장 주...
# 3           평일 사람 가게 내부 통로 이동 불편 종류 실패 애플 브리 치즈 샌드위치 기대
# 4                                대기 예상 메뉴 생각 추천 내부 이곳저곳
# ...                                                 ...
# 1804  대전 성심당 한국 유명 빵집 건물 대전 성심당 소금 소보로와 샌드위치 소금 버스 사...
# 1805                                                 선택
# 1806  인테리어 케이크 케이크 종류 품질 케이크 가격 제공 페이스트리 직원 친절 효율 제품...
# 1807                                           매장 쇼핑 기분
# 1808  크리스마스 케이크 픽업 최고 선택 매장 케이크 부티크 확인 즐거움 가방 구입 서울 ...
#
# [1809 rows x 1 columns]

# %%
newdf = newdf.astype(str)

# %%
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter


# 단어 카운트
all_words = ' '.join(newdf['clean_review']).split()
word_counts = Counter(all_words)

# 워드 클라우드 생성
wordcloud = WordCloud(
    font_path='/System/Library/Fonts/Supplemental/AppleGothic.ttf',  # Windows: 'malgun.ttf', macOS: '/System/Library/Fonts/Supplemental/AppleGothic.ttf'
    width=800,
    height=400,
    background_color='white'
).generate_from_frequencies(word_counts)

# 워드 클라우드 시각화
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # 축 제거
plt.title('Word Cloud for Clean Review', fontsize=16)
plt.show()

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TextClassificationPipeline
import pandas as pd

# 모델과 토크나이저 로드
model_name = "searle-j/kote_for_easygoing_people"
model = AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
pipe = TextClassificationPipeline(
    model=model,
    tokenizer=tokenizer,
    device=-1,  # GPU 번호 (-1은 CPU 사용)
    return_all_scores=True,
    function_to_apply='sigmoid'
)

# 감정 라벨
idx_finder = [
    '불평/불만', '환영/호의', '감동/감탄', '지긋지긋', '고마움', '슬픔', '화남/분노', '존경', '기대감', '우쭐댐/무시함', 
    '안타까움/실망', '비장함', '의심/불신', '뿌듯함', '편안/쾌적', '신기함/관심', '아껴주는', '부끄러움', '공포/무서움', 
    '절망', '한심함', '역겨움/징그러움', '짜증', '어이없음', '없음', '패배/자기혐오', '귀찮음', '힘듦/지침', 
    '즐거움/신남', '깨달음', '죄책감', '증오/혐오', '흐뭇함(귀여움/예쁨)', '당황/난처', '경악', '부담/안_내킴', 
    '서러움', '재미없음', '불쌍함/연민', '놀람', '행복', '불안/걱정', '기쁨', '안심/신뢰'
]

# 샘플 데이터프레임 생성 (테스트용)
# 실제 데이터를 사용하려면 newdf를 기존 데이터프레임으로 변경
# newdf = pd.DataFrame({
#     "clean_review": [
#         ["이 영화 정말 좋았어요", "배우 연기도 훌륭했습니다"],
#         ["별로였어요", "다시는 보고 싶지 않아요"],
#         ["정말 재미있고 감동적이었어요"],
#         "영화 자체는 나쁘지 않았지만 조금 지루했어요."
#     ]
# })

# 감정 분석 결과 저장 리스트
senti_list = []

for i in range(len(newdf)):
    # 텍스트 데이터 가져오기
    text_list = newdf.loc[i, "clean_review"]
    
    # 감정 점수 초기화
    senti_dict = [[label, 0] for label in idx_finder]

    # 텍스트 데이터가 리스트인지 확인
    if isinstance(text_list, str):
        text_list = [text_list]  # 문자열은 리스트로 변환

    if isinstance(text_list, list):
        # 텍스트 길이 제한
        text_list = [txt[:511] if len(txt) > 510 else txt for txt in text_list]
        sentence_num = len(text_list)

        # 감정 분석 실행
        results = pipe(text_list)

        # 결과를 senti_dict에 누적
        for sent_scores in results:
            for score_data in sent_scores:
                if score_data["score"] > 0.4:  # 임계값 0.4 이상만 처리
                    finder = idx_finder.index(score_data["label"])
                    senti_dict[finder][1] += score_data["score"]

        # 문장 수로 평균 계산
        emergency = []
        for sent in senti_dict:
            if sent[1] > 0:
                sent[1] /= sentence_num
                emergency.append(sent)

        senti_list.append(emergency)
    else:
        senti_list.append([""])  # 비어 있는 데이터 처리

    print(f"Processed {i + 1}/{len(newdf)} rows")

# 결과를 데이터프레임에 추가
newdf["sentiment"] = senti_list

# 결과를 CSV로 저장
newdf.to_csv("sentimental_analysis.csv", index=False)

# 확인용 출력
print(newdf.head())
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/transformers/pipelines/text_classification.py:106: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# Processed 1/1809 rows
# Processed 2/1809 rows
# Processed 3/1809 rows
# Processed 4/1809 rows
# Processed 5/1809 rows
# Processed 6/1809 rows
# Processed 7/1809 rows
# Processed 8/1809 rows
# Processed 9/1809 rows
# Processed 10/1809 rows
# Processed 11/1809 rows
# Processed 12/1809 rows
# Processed 13/1809 rows
# Processed 14/1809 rows
# Processed 15/1809 rows
# Processed 16/1809 rows
# Processed 17/1809 rows
# Processed 18/1809 rows
# Processed 19/1809 rows
# Processed 20/1809 rows
# Processed 21/1809 rows
# Processed 22/1809 rows
# Processed 23/1809 rows
# Processed 24/1809 rows
# Processed 25/1809 rows
# Processed 26/1809 rows
# Processed 27/1809 rows
# Processed 28/1809 rows
# Processed 29/1809 rows
# Processed 30/1809 rows
# Processed 31/1809 rows
# Processed 32/1809 rows
# Processed 33/1809 rows
# Processed 34/1809 rows
# Processed 35/1809 rows
# Processed 36/1809 rows
# Processed 37/1809 rows
# Processed 38/1809 rows
# Processed 39/1809 rows
# Processed 40/1809 rows
# Processed 41/1809 rows
# Processed 42/1809 rows
# Processed 43/1809 rows
# Processed 44/1809 rows
# Processed 45/1809 rows
# Processed 46/1809 rows
# Processed 47/1809 rows
# Processed 48/1809 rows
# Processed 49/1809 rows
# Processed 50/1809 rows
# Processed 51/1809 rows
# Processed 52/1809 rows
# Processed 53/1809 rows
# Processed 54/1809 rows
# Processed 55/1809 rows
# Processed 56/1809 rows
# Processed 57/1809 rows
# Processed 58/1809 rows
# Processed 59/1809 rows
# Processed 60/1809 rows
# Processed 61/1809 rows
# Processed 62/1809 rows
# Processed 63/1809 rows
# Processed 64/1809 rows
# Processed 65/1809 rows
# Processed 66/1809 rows
# Processed 67/1809 rows
# Processed 68/1809 rows
# Processed 69/1809 rows
# Processed 70/1809 rows
# Processed 71/1809 rows
# Processed 72/1809 rows
# Processed 73/1809 rows
# Processed 74/1809 rows
# Processed 75/1809 rows
# Processed 76/1809 rows
# Processed 77/1809 rows
# Processed 78/1809 rows
# Processed 79/1809 rows
# Processed 80/1809 rows
# Processed 81/1809 rows
# Processed 82/1809 rows
# Processed 83/1809 rows
# Processed 84/1809 rows
# Processed 85/1809 rows
# Processed 86/1809 rows
# Processed 87/1809 rows
# Processed 88/1809 rows
# Processed 89/1809 rows
# Processed 90/1809 rows
# Processed 91/1809 rows
# Processed 92/1809 rows
# Processed 93/1809 rows
# Processed 94/1809 rows
# Processed 95/1809 rows
# Processed 96/1809 rows
# Processed 97/1809 rows
# Processed 98/1809 rows
# Processed 99/1809 rows
# Processed 100/1809 rows
# Processed 101/1809 rows
# Processed 102/1809 rows
# Processed 103/1809 rows
# Processed 104/1809 rows
# Processed 105/1809 rows
# Processed 106/1809 rows
# Processed 107/1809 rows
# Processed 108/1809 rows
# Processed 109/1809 rows
# Processed 110/1809 rows
# Processed 111/1809 rows
# Processed 112/1809 rows
# Processed 113/1809 rows
# Processed 114/1809 rows
# Processed 115/1809 rows
# Processed 116/1809 rows
# Processed 117/1809 rows
# Processed 118/1809 rows
# Processed 119/1809 rows
# Processed 120/1809 rows
# Processed 121/1809 rows
# Processed 122/1809 rows
# Processed 123/1809 rows
# Processed 124/1809 rows
# Processed 125/1809 rows
# Processed 126/1809 rows
# Processed 127/1809 rows
# Processed 128/1809 rows
# Processed 129/1809 rows
# Processed 130/1809 rows
# Processed 131/1809 rows
# Processed 132/1809 rows
# Processed 133/1809 rows
# Processed 134/1809 rows
# Processed 135/1809 rows
# Processed 136/1809 rows
# Processed 137/1809 rows
# Processed 138/1809 rows
# Processed 139/1809 rows
# Processed 140/1809 rows
# Processed 141/1809 rows
# Processed 142/1809 rows
# Processed 143/1809 rows
# Processed 144/1809 rows
# Processed 145/1809 rows
# Processed 146/1809 rows
# Processed 147/1809 rows
# Processed 148/1809 rows
# Processed 149/1809 rows
# Processed 150/1809 rows
# Processed 151/1809 rows
# Processed 152/1809 rows
# Processed 153/1809 rows
# Processed 154/1809 rows
# Processed 155/1809 rows
# Processed 156/1809 rows
# Processed 157/1809 rows
# Processed 158/1809 rows
# Processed 519/1809 rows
# Processed 520/1809 rows
# Processed 521/1809 rows
# Processed 522/1809 rows
# Processed 523/1809 rows
# Processed 524/1809 rows
# Processed 525/1809 rows
# Processed 526/1809 rows
# Processed 527/1809 rows
# Processed 528/1809 rows
# Processed 529/1809 rows
# Processed 530/1809 rows
# Processed 531/1809 rows
# Processed 532/1809 rows
# Processed 533/1809 rows
# Processed 534/1809 rows
# Processed 535/1809 rows
# Processed 536/1809 rows
# Processed 537/1809 rows
# Processed 538/1809 rows
# Processed 539/1809 rows
# Processed 540/1809 rows
# Processed 541/1809 rows
# Processed 542/1809 rows
# Processed 543/1809 rows
# Processed 544/1809 rows
# Processed 545/1809 rows
# Processed 546/1809 rows
# Processed 547/1809 rows
# Processed 548/1809 rows
# Processed 549/1809 rows
# Processed 550/1809 rows
# Processed 551/1809 rows
# Processed 552/1809 rows
# Processed 553/1809 rows
# Processed 554/1809 rows
# Processed 555/1809 rows
# Processed 556/1809 rows
# Processed 557/1809 rows
# Processed 558/1809 rows
# Processed 559/1809 rows
# Processed 560/1809 rows
# Processed 561/1809 rows
# Processed 562/1809 rows
# Processed 563/1809 rows
# Processed 564/1809 rows
# Processed 565/1809 rows
# Processed 566/1809 rows
# Processed 567/1809 rows
# Processed 568/1809 rows
# Processed 569/1809 rows
# Processed 570/1809 rows
# Processed 571/1809 rows
# Processed 572/1809 rows
# Processed 573/1809 rows
# Processed 574/1809 rows
# Processed 575/1809 rows
# Processed 576/1809 rows
# Processed 577/1809 rows
# Processed 578/1809 rows
# Processed 579/1809 rows
# Processed 580/1809 rows
# Processed 581/1809 rows
# Processed 582/1809 rows
# Processed 583/1809 rows
# Processed 584/1809 rows
# Processed 585/1809 rows
# Processed 586/1809 rows
# Processed 587/1809 rows
# Processed 588/1809 rows
# Processed 589/1809 rows
# Processed 590/1809 rows
# Processed 591/1809 rows
# Processed 592/1809 rows
# Processed 593/1809 rows
# Processed 594/1809 rows
# Processed 595/1809 rows
# Processed 596/1809 rows
# Processed 597/1809 rows
# Processed 598/1809 rows
# Processed 599/1809 rows
# Processed 600/1809 rows
# Processed 601/1809 rows
# Processed 602/1809 rows
# Processed 603/1809 rows
# Processed 604/1809 rows
# Processed 605/1809 rows
# Processed 606/1809 rows
# Processed 607/1809 rows
# Processed 608/1809 rows
# Processed 609/1809 rows
# Processed 610/1809 rows
# Processed 611/1809 rows
# Processed 612/1809 rows
# Processed 613/1809 rows
# Processed 614/1809 rows
# Processed 615/1809 rows
# Processed 616/1809 rows
# Processed 617/1809 rows
# Processed 618/1809 rows
# Processed 619/1809 rows
# Processed 620/1809 rows
# Processed 621/1809 rows
# Processed 622/1809 rows
# Processed 623/1809 rows
# Processed 624/1809 rows
# Processed 625/1809 rows
# Processed 626/1809 rows
# Processed 627/1809 rows
# Processed 628/1809 rows
# Processed 629/1809 rows
# Processed 630/1809 rows
# Processed 631/1809 rows
# Processed 632/1809 rows
# Processed 633/1809 rows
# Processed 634/1809 rows
# Processed 635/1809 rows
# Processed 636/1809 rows
# Processed 637/1809 rows
# Processed 638/1809 rows
# Processed 639/1809 rows
# Processed 640/1809 rows
# Processed 641/1809 rows
# Processed 642/1809 rows
# Processed 643/1809 rows
# Processed 644/1809 rows
# Processed 645/1809 rows
# Processed 646/1809 rows
# Processed 647/1809 rows
# Processed 648/1809 rows
# Processed 649/1809 rows
# Processed 650/1809 rows
# Processed 651/1809 rows
# Processed 652/1809 rows
# Processed 653/1809 rows
# Processed 654/1809 rows
# Processed 655/1809 rows
# Processed 656/1809 rows
# Processed 657/1809 rows
# Processed 658/1809 rows
# Processed 659/1809 rows
# Processed 660/1809 rows
# Processed 661/1809 rows
# Processed 662/1809 rows
# Processed 663/1809 rows
# Processed 664/1809 rows
# Processed 665/1809 rows
# Processed 666/1809 rows
# Processed 667/1809 rows
# Processed 668/1809 rows
# Processed 669/1809 rows
# Processed 670/1809 rows
# Processed 671/1809 rows
# Processed 672/1809 rows
# Processed 673/1809 rows
# Processed 674/1809 rows
# Processed 675/1809 rows
# Processed 676/1809 rows
# Processed 677/1809 rows
# Processed 678/1809 rows
# Processed 679/1809 rows
# Processed 680/1809 rows
# Processed 681/1809 rows
# Processed 682/1809 rows
# Processed 683/1809 rows
# Processed 684/1809 rows
# Processed 685/1809 rows
# Processed 686/1809 rows
# Processed 687/1809 rows
# Processed 688/1809 rows
# Processed 689/1809 rows
# Processed 690/1809 rows
# Processed 691/1809 rows
# Processed 692/1809 rows
# Processed 693/1809 rows
# Processed 694/1809 rows
# Processed 695/1809 rows
# Processed 696/1809 rows
# Processed 697/1809 rows
# Processed 698/1809 rows
# Processed 699/1809 rows
# Processed 700/1809 rows
# Processed 701/1809 rows
# Processed 702/1809 rows
# Processed 703/1809 rows
# Processed 704/1809 rows
# Processed 705/1809 rows
# Processed 706/1809 rows
# Processed 707/1809 rows
# Processed 708/1809 rows
# Processed 709/1809 rows
# Processed 710/1809 rows
# Processed 711/1809 rows
# Processed 712/1809 rows
# Processed 713/1809 rows
# Processed 714/1809 rows
# Processed 715/1809 rows
# Processed 716/1809 rows
# Processed 717/1809 rows
# Processed 718/1809 rows
# Processed 719/1809 rows
# Processed 720/1809 rows
# Processed 721/1809 rows
# Processed 722/1809 rows
# Processed 723/1809 rows
# Processed 724/1809 rows
# Processed 725/1809 rows
# Processed 726/1809 rows
# Processed 727/1809 rows
# Processed 728/1809 rows
# Processed 729/1809 rows
# Processed 730/1809 rows
# Processed 731/1809 rows
# Processed 732/1809 rows
# Processed 733/1809 rows
# Processed 734/1809 rows
# Processed 735/1809 rows
# Processed 736/1809 rows
# Processed 737/1809 rows
# Processed 738/1809 rows
# Processed 739/1809 rows
# Processed 740/1809 rows
# Processed 741/1809 rows
# Processed 742/1809 rows
# Processed 743/1809 rows
# Processed 744/1809 rows
# Processed 745/1809 rows
# Processed 746/1809 rows
# Processed 747/1809 rows
# Processed 748/1809 rows
# Processed 749/1809 rows
# Processed 750/1809 rows
# Processed 751/1809 rows
# Processed 752/1809 rows
# Processed 753/1809 rows
# Processed 754/1809 rows
# Processed 755/1809 rows
# Processed 756/1809 rows
# Processed 757/1809 rows
# Processed 758/1809 rows
# Processed 879/1809 rows
# Processed 880/1809 rows
# Processed 881/1809 rows
# Processed 882/1809 rows
# Processed 883/1809 rows
# Processed 884/1809 rows
# Processed 885/1809 rows
# Processed 886/1809 rows
# Processed 887/1809 rows
# Processed 888/1809 rows
# Processed 889/1809 rows
# Processed 890/1809 rows
# Processed 891/1809 rows
# Processed 892/1809 rows
# Processed 893/1809 rows
# Processed 894/1809 rows
# Processed 895/1809 rows
# Processed 896/1809 rows
# Processed 897/1809 rows
# Processed 898/1809 rows
# Processed 899/1809 rows
# Processed 900/1809 rows
# Processed 901/1809 rows
# Processed 902/1809 rows
# Processed 903/1809 rows
# Processed 904/1809 rows
# Processed 905/1809 rows
# Processed 906/1809 rows
# Processed 907/1809 rows
# Processed 908/1809 rows
# Processed 909/1809 rows
# Processed 910/1809 rows
# Processed 911/1809 rows
# Processed 912/1809 rows
# Processed 913/1809 rows
# Processed 914/1809 rows
# Processed 915/1809 rows
# Processed 916/1809 rows
# Processed 917/1809 rows
# Processed 918/1809 rows
# Processed 919/1809 rows
# Processed 920/1809 rows
# Processed 921/1809 rows
# Processed 922/1809 rows
# Processed 923/1809 rows
# Processed 924/1809 rows
# Processed 925/1809 rows
# Processed 926/1809 rows
# Processed 927/1809 rows
# Processed 928/1809 rows
# Processed 929/1809 rows
# Processed 930/1809 rows
# Processed 931/1809 rows
# Processed 932/1809 rows
# Processed 933/1809 rows
# Processed 934/1809 rows
# Processed 935/1809 rows
# Processed 936/1809 rows
# Processed 937/1809 rows
# Processed 938/1809 rows
# Processed 939/1809 rows
# Processed 940/1809 rows
# Processed 941/1809 rows
# Processed 942/1809 rows
# Processed 943/1809 rows
# Processed 944/1809 rows
# Processed 945/1809 rows
# Processed 946/1809 rows
# Processed 947/1809 rows
# Processed 948/1809 rows
# Processed 949/1809 rows
# Processed 950/1809 rows
# Processed 951/1809 rows
# Processed 952/1809 rows
# Processed 953/1809 rows
# Processed 954/1809 rows
# Processed 955/1809 rows
# Processed 956/1809 rows
# Processed 957/1809 rows
# Processed 958/1809 rows
# Processed 959/1809 rows
# Processed 960/1809 rows
# Processed 961/1809 rows
# Processed 962/1809 rows
# Processed 963/1809 rows
# Processed 964/1809 rows
# Processed 965/1809 rows
# Processed 966/1809 rows
# Processed 967/1809 rows
# Processed 968/1809 rows
# Processed 969/1809 rows
# Processed 970/1809 rows
# Processed 971/1809 rows
# Processed 972/1809 rows
# Processed 973/1809 rows
# Processed 974/1809 rows
# Processed 975/1809 rows
# Processed 976/1809 rows
# Processed 977/1809 rows
# Processed 978/1809 rows
# Processed 979/1809 rows
# Processed 980/1809 rows
# Processed 981/1809 rows
# Processed 982/1809 rows
# Processed 983/1809 rows
# Processed 984/1809 rows
# Processed 985/1809 rows
# Processed 986/1809 rows
# Processed 987/1809 rows
# Processed 988/1809 rows
# Processed 989/1809 rows
# Processed 990/1809 rows
# Processed 991/1809 rows
# Processed 992/1809 rows
# Processed 993/1809 rows
# Processed 994/1809 rows
# Processed 995/1809 rows
# Processed 996/1809 rows
# Processed 997/1809 rows
# Processed 998/1809 rows
# Processed 1779/1809 rows
# Processed 1780/1809 rows
# Processed 1781/1809 rows
# Processed 1782/1809 rows
# Processed 1783/1809 rows
# Processed 1784/1809 rows
# Processed 1785/1809 rows
# Processed 1786/1809 rows
# Processed 1787/1809 rows
# Processed 1788/1809 rows
# Processed 1789/1809 rows
# Processed 1790/1809 rows
# Processed 1791/1809 rows
# Processed 1792/1809 rows
# Processed 1793/1809 rows
# Processed 1794/1809 rows
# Processed 1795/1809 rows
# Processed 1796/1809 rows
# Processed 1797/1809 rows
# Processed 1798/1809 rows
# Processed 1799/1809 rows
# Processed 1800/1809 rows
# Processed 1801/1809 rows
# Processed 1802/1809 rows
# Processed 1803/1809 rows
# Processed 1804/1809 rows
# Processed 1805/1809 rows
# Processed 1806/1809 rows
# Processed 1807/1809 rows
# Processed 1808/1809 rows
# Processed 1809/1809 rows
#                                         clean_review  \
# 0  대전 용운 국제 수영장 대회 천안 성심당 본점 위치 상황 정오 주차장 주차 네이버 ...
# 1                 봉지 부띠끄 사람 비닐 주심 센스 메아리 대전 사람 다음 대전
# 2  대전 여행 알파 오메가 성심당 본점 대전 시내 위치 기차 도보 거리 주차 주차장 주...
# 3        평일 사람 가게 내부 통로 이동 불편 종류 실패 애플 브리 치즈 샌드위치 기대
# 4                             대기 예상 메뉴 생각 추천 내부 이곳저곳
#
#                                            sentiment
# 0  [[환영/호의, 0.6519662737846375], [기대감, 0.80426084...
# 1  [[환영/호의, 0.7073864936828613], [감동/감탄, 0.595750...
# 2  [[환영/호의, 0.8114428520202637], [감동/감탄, 0.469294...
# 3  [[기대감, 0.8496021628379822], [안타까움/실망, 0.535938...
# 4  [[환영/호의, 0.5734164714813232], [기대감, 0.93250894...

# %%
import pandas as pd

# CSV 파일 불러오기 (예제에 맞게 경로 변경)
review_df = pd.read_csv("sentimental_analysis.csv")

# sentiment 열에서 가장 큰 점수를 가진 감정만 추출
def get_top_sentiment(sentiments):
    try:
        # 문자열을 리스트로 변환
        sentiments = eval(sentiments)  
        # 가장 큰 점수를 가진 감정을 반환
        if sentiments:
            return max(sentiments, key=lambda x: x[1])
        else:
            return None
    except:
        return None

# 새로운 열에 상위 감정 저장
review_df["top_sentiment"] = review_df["sentiment"].apply(get_top_sentiment)

# top_sentiment에서 라벨과 점수를 분리
review_df["top_sentiment_label"] = review_df["top_sentiment"].apply(lambda x: x[0] if x else None)
review_df["top_sentiment_score"] = review_df["top_sentiment"].apply(lambda x: x[1] if x else None)

# 필요한 컬럼만 서브셋
subset_df = review_df[["clean_review", "top_sentiment_label", "top_sentiment_score"]]

# 결과 확인
print(subset_df)

# 새로운 CSV 저장
subset_df.to_csv("top_sentiments_subset.csv", index=False)
# Out:
#                                            clean_review top_sentiment_label  \
# 0     대전 용운 국제 수영장 대회 천안 성심당 본점 위치 상황 정오 주차장 주차 네이버 ...              즐거움/신남
# 1                    봉지 부띠끄 사람 비닐 주심 센스 메아리 대전 사람 다음 대전              즐거움/신남
# 2     대전 여행 알파 오메가 성심당 본점 대전 시내 위치 기차 도보 거리 주차 주차장 주...                 기대감
# 3           평일 사람 가게 내부 통로 이동 불편 종류 실패 애플 브리 치즈 샌드위치 기대                 기대감
# 4                                대기 예상 메뉴 생각 추천 내부 이곳저곳                 기대감
# ...                                                 ...                 ...
# 1804  대전 성심당 한국 유명 빵집 건물 대전 성심당 소금 소보로와 샌드위치 소금 버스 사...                  없음
# 1805                                                 선택                  없음
# 1806  인테리어 케이크 케이크 종류 품질 케이크 가격 제공 페이스트리 직원 친절 효율 제품...                 기대감
# 1807                                           매장 쇼핑 기분              즐거움/신남
# 1808  크리스마스 케이크 픽업 최고 선택 매장 케이크 부티크 확인 즐거움 가방 구입 서울 ...              즐거움/신남
#
#       top_sentiment_score
# 0                0.841205
# 1                0.726920
# 2                0.936075
# 3                0.849602
# 4                0.932509
# ...                   ...
# 1804             0.893034
# 1805             0.934584
# 1806             0.946143
# 1807             0.854372
# 1808             0.965319
#
# [1809 rows x 3 columns]

# %%
df11.shape # 208 0~ 207
df22.shape # 897 208 ~ 1104
df33.shape # 704 1105 ~ 1808

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd

# 한글 폰트 설정 (예: 맑은 고딕)
# plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows
plt.rcParams['font.family'] = 'AppleGothic'  # macOS
# plt.rcParams['font.family'] = 'NanumGothic'  # Linux (nanum 설치 필요)
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# 레이블별 빈도 계산
label_counts = subset_df["top_sentiment_label"].value_counts()

# 시각화
plt.figure(figsize=(10, 6))
label_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Top Sentiment Label Distribution", fontsize=16)
plt.xlabel("Sentiment Label", fontsize=12)
plt.ylabel("Frequency", fontsize=12)

# X축 레이블 회전
plt.xticks(rotation=30, ha='right', fontsize=10)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV 파일 불러오기
review_df = pd.read_csv("sentimental_analysis.csv")

# sentiment 열에서 가장 큰 점수를 가진 감정 추출
review_df["top_sentiment"] = review_df["sentiment"].apply(get_top_sentiment)

# top_sentiment에서 라벨과 점수 분리
review_df["top_sentiment_label"] = review_df["top_sentiment"].apply(lambda x: x[0] if x else None)
review_df["top_sentiment_score"] = review_df["top_sentiment"].apply(lambda x: x[1] if x else None)

# 데이터프레임 분할
df11 = review_df.iloc[0:208]
df22 = review_df.iloc[208:1105]
df33 = review_df.iloc[1105:1809]

# 상위 5개 추출 함수
def extract_top5(df):
    if "top_sentiment_score" not in df.columns:
        raise KeyError("The column 'top_sentiment_score' does not exist in the DataFrame.")
    return df.nlargest(5, "top_sentiment_score")[["clean_review", "top_sentiment_label", "top_sentiment_score"]]

# 상위 5개 추출
top5_df11 = extract_top5(df11)
top5_df22 = extract_top5(df22)
top5_df33 = extract_top5(df33)

# 상위 5개 감정 데이터프레임 합치기
top5_all = pd.concat([
    top5_df11.assign(Source="df11"),
    top5_df22.assign(Source="df22"),
    top5_df33.assign(Source="df33")
])

# 결과 CSV 저장
top5_all.to_csv("top5_sentiments_comparison.csv", index=False)

# 감정별 비교 시각화
plt.figure(figsize=(10, 6))

# 각 데이터프레임의 상위 5개 감정 점수를 바 차트로 표현
for source, group in top5_all.groupby("Source"):
    plt.bar(group["top_sentiment_label"], group["top_sentiment_score"], label=source, alpha=0.7)

plt.title("Top 5 Sentiments Comparison Across Subsets", fontsize=16)
plt.xlabel("Sentiment Label", fontsize=12)
plt.ylabel("Sentiment Score", fontsize=12)
plt.legend(title="Subset", fontsize=10)
plt.xticks(rotation=30, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 감정 빈도를 계산하고 상위 5개만 플롯을 그리는 함수
def plot_top5_frequency_excluding_none(df, source_name):
    sentiment_frequency = df["top_sentiment_label"].value_counts()
    sentiment_frequency = sentiment_frequency[sentiment_frequency.index != "없음"]  # "없음" 제외
    top5_sentiments = sentiment_frequency.nlargest(5)  # 상위 5개 선택
    plt.figure(figsize=(8, 5))
    top5_sentiments.plot(kind="bar", color="skyblue", edgecolor="black")
    plt.title(f"Top 5 Sentiment Frequencies for {source_name}", fontsize=16)
    plt.xlabel("Sentiment Label", fontsize=12)
    plt.ylabel("Frequency", fontsize=12)
    plt.xticks(rotation=30, ha="right", fontsize=10)
    plt.tight_layout()
    plt.show()

# 상위 5개 빈도 플롯 생성 (없음 제외)
plot_top5_frequency_excluding_none(df11, "df11")
plot_top5_frequency_excluding_none(df22, "df22")
plot_top5_frequency_excluding_none(df33, "df33")

# %%
import matplotlib.pyplot as plt

# 각 데이터프레임의 상위 5개 빈도 데이터 가져오기
def get_top5_frequencies(df, source_name):
    sentiment_frequency = df["top_sentiment_label"].value_counts()
    sentiment_frequency = sentiment_frequency[sentiment_frequency.index != "없음"]  # "없음" 제외
    return sentiment_frequency.nlargest(5).rename(source_name)

# 빈도 데이터 수집
freq_df11 = get_top5_frequencies(df11, "DiningCode")
freq_df22 = get_top5_frequencies(df22, "Kakao")
freq_df33 = get_top5_frequencies(df33, "Google")

# 데이터를 하나의 데이터프레임으로 병합
all_freqs = pd.concat([freq_df11, freq_df22, freq_df33], axis=1).fillna(0)

# 하나의 그래프에서 비교
plt.figure(figsize=(10, 6))
all_freqs.plot(kind="bar", figsize=(10, 6), color=["skyblue", "orange", "green"], edgecolor="black")
plt.title("Top 5 Sentiment Frequencies Comparison", fontsize=16)
plt.xlabel("Sentiment Label", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.xticks(rotation=30, ha="right", fontsize=10)
plt.legend(title="Dataset", fontsize=10)
plt.tight_layout()
plt.show()

# %%
newdf
# Out:
#                                            clean_review
# 0     대전 용운 국제 수영장 대회 천안 성심당 본점 위치 상황 정오 주차장 주차 네이버 ...
# 1                    봉지 부띠끄 사람 비닐 주심 센스 메아리 대전 사람 다음 대전
# 2     대전 여행 알파 오메가 성심당 본점 대전 시내 위치 기차 도보 거리 주차 주차장 주...
# 3           평일 사람 가게 내부 통로 이동 불편 종류 실패 애플 브리 치즈 샌드위치 기대
# 4                                대기 예상 메뉴 생각 추천 내부 이곳저곳
# ...                                                 ...
# 1374                          친절하고 맛있고 가끔대전갈때마다 꼭 들르게 됨
# 1375                                              좋은 가게
# 1376   속을 채운 빵들부추빵 튀소 크림빵 등이 맛있어요 빵도 많아서 빵돌이 빵순이의 천국입니다
# 1377               확실히 대전역점보다 다양하고 깔끔한 느낌가격도 파리바게트보다 싼듯
# 1378                      제가 이때까지 먹었던 빵중에 가장 맛있는 빵이 파네요
#
# [1379 rows x 1 columns]
